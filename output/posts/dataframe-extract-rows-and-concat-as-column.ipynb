# %% [markdown]
# # [FAQ] DataFrame 행(row) 정보를 추출하여 컬럼으로 합치기
# 크롤링 데이터 가공과 결측치 처리 예제 (Daum 부동산 예제)
#
# * Q: DataFrame의 두 행(row)이 하나의 데이터를 이룹니다. 짝수 행의 데이터를 추출하여 컬럼으로 만드려면 어떻게 하나요?
# * A: DataFrame.ix[] 인덱싱을 사용하여 짝수행 전체를 얻어 가공하고, pd.concat()을 이용여 합칠 수 있습니다.
#
# <img width="320" src="http://i.imgur.com/9WYp6pK.png" >
#
# #### http://fb.com/financedata
# <!-- TEASER_END -->

# %%
import pandas as pd

url = "http://realestate.daum.net/iframe/maemul/maemulList.daum?areaCode=2130010&mcateCode=A1&saleTypeCode=S&tabName=maemulList&isExpanded=false&page=1"
dfs = pd.read_html(url)

# %% [markdown]
# <img src="http://i.imgur.com/kFxXIcw.png" >

# %%
# 2개의 DataFrame을 읽었다

len(dfs)
# Out:
# 2

# %% [markdown]
# 두번째 DataFrame을 얻는다.
#
# 총 60 행(row)이지만, 2개의 행(row)가 하나의 데이터를 이루고 있다. 짝수번째 행(row)는 부가적인 설명이 있다.

# %%
df = dfs[1] 
print(len(df), 'rows')

df.head(10)
# Out:
# 60 rows
#                          최초게재일 \t종류/소재지\t           \t단지명\t  \
# 0                 매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 1  급매물  확장형  25 ㅇ 확장형 쾌적한 주거환경        NaN               NaN
# 2                 매매  17.03.01     아파트이문동            쌍용  쌍용
# 3  대단지  무융자  일조권좋은집 ,거실및 방확장 ,        NaN               NaN
# 4                 매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 5                확장형  신축  착한가격        NaN               NaN
# 6                 매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 7                     역세권  확장형        NaN               NaN
# 8                 매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 9     전월세끼고  확장형  전세 안고 저렴한 매매        NaN               NaN
#
#                        \t\t\t공급/전용(㎡)\t\t  \t    매매가(만원)\t  \t\t\t동\t\t  \
# 0      85A/59  공급면적  85.28㎡  전용면적  59.99㎡            54000          308
# 1                                     NaN              NaN          NaN
# 2       81/59  공급면적  81.19㎡  전용면적  59.99㎡            35000          110
# 3                                     NaN              NaN          NaN
# 4    111A/84  공급면적  111.47㎡  전용면적  84.99㎡            62000          310
# 5                                     NaN              NaN          NaN
# 6  150B/114  공급면적  150.19㎡  전용면적  114.96㎡            71000          107
# 7                                     NaN              NaN          NaN
# 8    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59500          106
# 9                                     NaN              NaN          NaN
#
#   \t\t\t층\t                     \t문의처\t
# 0      저/14  황금단지내공인중개. .  02-2246-5252
# 1       NaN                         NaN
# 2      중/25   쌍용공인중개사사무. .  02-962-2244
# 3       NaN                         NaN
# 4      중/15  황금단지내부동산공. .  02-2247-5252
# 5       NaN                         NaN
# 6      8/20   미래공인중개사사무. .  02-960-6800
# 7       NaN                         NaN
# 8      5/20   미래공인중개사사무. .  02-960-6800
# 9       NaN                         NaN

# %% [markdown]
# 짝수번째 행(인덱스가 1,3,5,7..)은 NaN을 포함하고 있다.
#
# 가장 간단한 방법은  NaN을 가지고 있는 행을 제거(drop)하는 것이다. (DataFrame.dropna)

# %%
df = df.dropna()
print(len(df), 'rows')

df.head(10)
# Out:
# 30 rows
#            최초게재일 \t종류/소재지\t           \t단지명\t  \
# 0   매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 2   매매  17.03.01     아파트이문동            쌍용  쌍용
# 4   매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 6   매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 8   매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 10  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 12  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 14  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 16  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 18  매매  17.03.01     아파트이문동            현대  현대
#
#                         \t\t\t공급/전용(㎡)\t\t  \t    매매가(만원)\t  \t\t\t동\t\t  \
# 0       85A/59  공급면적  85.28㎡  전용면적  59.99㎡            54000          308
# 2        81/59  공급면적  81.19㎡  전용면적  59.99㎡            35000          110
# 4     111A/84  공급면적  111.47㎡  전용면적  84.99㎡            62000          310
# 6   150B/114  공급면적  150.19㎡  전용면적  114.96㎡            71000          107
# 8     111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59500          106
# 10    112A/84  공급면적  112.33㎡  전용면적  84.97㎡            61000          104
# 12    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59000          108
# 14  150A/114  공급면적  150.53㎡  전용면적  114.98㎡            71000          105
# 16  150A/114  공급면적  150.53㎡  전용면적  114.98㎡            70000          107
# 18    107N/84  공급면적  107.94㎡  전용면적  84.56㎡            40000          103
#
#    \t\t\t층\t                     \t문의처\t
# 0       저/14  황금단지내공인중개. .  02-2246-5252
# 2       중/25   쌍용공인중개사사무. .  02-962-2244
# 4       중/15  황금단지내부동산공. .  02-2247-5252
# 6       8/20   미래공인중개사사무. .  02-960-6800
# 8       5/20   미래공인중개사사무. .  02-960-6800
# 10      고/20      백산 공인중개사  02-3291-0088
# 12      저/20      백산 공인중개사  02-3291-0088
# 14      5/20      백산 공인중개사  02-3291-0088
# 16      중/20      백산 공인중개사  02-3291-0088
# 18      중/21   쌍용공인중개사사무. .  02-962-2244

# %% [markdown]
# # DataFrame의 행,열 조작

# %%
# ix[] 인덱싱을 사용하여 짝수번째 행(row)만 추출한다.

df1 = df.ix[::2,:]

print(len(df1), 'rows')
df1.head(10)
# Out:
# 15 rows
#            최초게재일 \t종류/소재지\t           \t단지명\t  \
# 0   매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 4   매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 8   매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 12  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 16  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 20  매매  17.03.01    아파트답십리동      답십리대우  답십리대우
# 24  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 28  매매  17.03.01     아파트이문동            쌍용  쌍용
# 32  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 36  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
#
#                         \t\t\t공급/전용(㎡)\t\t  \t    매매가(만원)\t  \t\t\t동\t\t  \
# 0       85A/59  공급면적  85.28㎡  전용면적  59.99㎡            54000          308
# 4     111A/84  공급면적  111.47㎡  전용면적  84.99㎡            62000          310
# 8     111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59500          106
# 12    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59000          108
# 16  150A/114  공급면적  150.53㎡  전용면적  114.98㎡            70000          107
# 20       89/59  공급면적  89.12㎡  전용면적  59.76㎡            39000          101
# 24       80B/59  공급면적  80.37㎡  전용면적  59.9㎡            54000          103
# 28       81/59  공급면적  81.19㎡  전용면적  59.99㎡            34000          115
# 32       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            55000          101
# 36       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            54000          102
#
#    \t\t\t층\t                     \t문의처\t
# 0       저/14  황금단지내공인중개. .  02-2246-5252
# 4       중/15  황금단지내부동산공. .  02-2247-5252
# 8       5/20   미래공인중개사사무. .  02-960-6800
# 12      저/20      백산 공인중개사  02-3291-0088
# 16      중/20      백산 공인중개사  02-3291-0088
# 20      중/22  금강부동산공인중개. .  02-2245-0006
# 24      중/20      백산 공인중개사  02-3291-0088
# 28     25/25   쌍용공인중개사사무. .  02-962-2244
# 32     13/20   미래공인중개사사무. .  02-960-6800
# 36     11/19   미래공인중개사사무. .  02-960-6800

# %%
# 이번에는 홀수번째 행(row)만 추출한다.

df2 = df.ix[1::2, 0]
df2.name = '비고'
df2.head(10)
# Out:
# 2     매매  17.03.01
# 6     매매  17.03.01
# 10    매매  17.03.01
# 14    매매  17.03.01
# 18    매매  17.03.01
# 22    매매  17.03.01
# 26    매매  17.03.01
# 30    매매  17.03.01
# 34    매매  17.03.01
# 38    매매  17.03.01
# Name: 비고, dtype: object

# %%
# df1과 df2를 합치기(concat)위해 위해 index를 동일하게 초기화 한다.
df1.reset_index(drop=True , inplace=True)
df2.reset_index(drop=True , inplace=True)

# df1 과  df2 를 컬럼으로 합치기
result = pd.concat([df1, df2], axis=1)
result.head(10)
# Out:
#           최초게재일 \t종류/소재지\t           \t단지명\t  \
# 0  매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 1  매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 2  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 3  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 4  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 5  매매  17.03.01    아파트답십리동      답십리대우  답십리대우
# 6  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 7  매매  17.03.01     아파트이문동            쌍용  쌍용
# 8  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 9  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
#
#                        \t\t\t공급/전용(㎡)\t\t  \t    매매가(만원)\t  \t\t\t동\t\t  \
# 0      85A/59  공급면적  85.28㎡  전용면적  59.99㎡            54000          308
# 1    111A/84  공급면적  111.47㎡  전용면적  84.99㎡            62000          310
# 2    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59500          106
# 3    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59000          108
# 4  150A/114  공급면적  150.53㎡  전용면적  114.98㎡            70000          107
# 5       89/59  공급면적  89.12㎡  전용면적  59.76㎡            39000          101
# 6       80B/59  공급면적  80.37㎡  전용면적  59.9㎡            54000          103
# 7       81/59  공급면적  81.19㎡  전용면적  59.99㎡            34000          115
# 8       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            55000          101
# 9       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            54000          102
#
#   \t\t\t층\t                     \t문의처\t            비고
# 0      저/14  황금단지내공인중개. .  02-2246-5252  매매  17.03.01
# 1      중/15  황금단지내부동산공. .  02-2247-5252  매매  17.03.01
# 2      5/20   미래공인중개사사무. .  02-960-6800  매매  17.03.01
# 3      저/20      백산 공인중개사  02-3291-0088  매매  17.03.01
# 4      중/20      백산 공인중개사  02-3291-0088  매매  17.03.01
# 5      중/22  금강부동산공인중개. .  02-2245-0006  매매  17.03.01
# 6      중/20      백산 공인중개사  02-3291-0088  매매  17.03.01
# 7     25/25   쌍용공인중개사사무. .  02-962-2244  매매  17.03.01
# 8     13/20   미래공인중개사사무. .  02-960-6800  매매  17.03.01
# 9     11/19   미래공인중개사사무. .  02-960-6800  매매  17.03.01

# %% [markdown]
# # 컬럼 다듬기
#
#
# '최초게재일' 컬럼에 거래종류와 날짜가 함께 있다. 거래종류는 매매, 전세, 월세 등이 있다.
# 이 데이터를 둘로 나누어 각각 '거래종류'를 추출하고, '최초게제일'에는 날짜만 남도록 해보자.
#
# Series.str.extract() 에 정규식을 사용하여 매치되는 문자열을 추출할 수 있다.

# %%
# '매매 17.03.01' 데이터에 대해,
# 정규식 '(.*) '을 적용하면 '매매'만 추출

result['거래종류'] = result['최초게재일'].str.extract('(.*) ')
result.head(10)
# Out:
#           최초게재일 \t종류/소재지\t           \t단지명\t  \
# 0  매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 1  매매  17.03.01    아파트답십리동      래미안위브  래미안위브
# 2  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 3  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 4  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 5  매매  17.03.01    아파트답십리동      답십리대우  답십리대우
# 6  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 7  매매  17.03.01     아파트이문동            쌍용  쌍용
# 8  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 9  매매  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
#
#                        \t\t\t공급/전용(㎡)\t\t  \t    매매가(만원)\t  \t\t\t동\t\t  \
# 0      85A/59  공급면적  85.28㎡  전용면적  59.99㎡            54000          308
# 1    111A/84  공급면적  111.47㎡  전용면적  84.99㎡            62000          310
# 2    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59500          106
# 3    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59000          108
# 4  150A/114  공급면적  150.53㎡  전용면적  114.98㎡            70000          107
# 5       89/59  공급면적  89.12㎡  전용면적  59.76㎡            39000          101
# 6       80B/59  공급면적  80.37㎡  전용면적  59.9㎡            54000          103
# 7       81/59  공급면적  81.19㎡  전용면적  59.99㎡            34000          115
# 8       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            55000          101
# 9       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            54000          102
#
#   \t\t\t층\t                     \t문의처\t            비고 거래종류
# 0      저/14  황금단지내공인중개. .  02-2246-5252  매매  17.03.01  매매
# 1      중/15  황금단지내부동산공. .  02-2247-5252  매매  17.03.01  매매
# 2      5/20   미래공인중개사사무. .  02-960-6800  매매  17.03.01  매매
# 3      저/20      백산 공인중개사  02-3291-0088  매매  17.03.01  매매
# 4      중/20      백산 공인중개사  02-3291-0088  매매  17.03.01  매매
# 5      중/22  금강부동산공인중개. .  02-2245-0006  매매  17.03.01  매매
# 6      중/20      백산 공인중개사  02-3291-0088  매매  17.03.01  매매
# 7     25/25   쌍용공인중개사사무. .  02-962-2244  매매  17.03.01  매매
# 8     13/20   미래공인중개사사무. .  02-960-6800  매매  17.03.01  매매
# 9     11/19   미래공인중개사사무. .  02-960-6800  매매  17.03.01  매매

# %%
# '매매 17.03.01' 데이터에 대해, 
# 정규식 '(\d+.\d+.\d+)'을 적용하여 추출하면 '17.03.01'만 추출

result['최초게재일'] = result['최초게재일'].str.extract('(\d+.\d+.\d+)')
result.head(10)
# Out:
#       최초게재일 \t종류/소재지\t           \t단지명\t  \
# 0  17.03.01    아파트답십리동      래미안위브  래미안위브
# 1  17.03.01    아파트답십리동      래미안위브  래미안위브
# 2  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 3  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 4  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 5  17.03.01    아파트답십리동      답십리대우  답십리대우
# 6  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 7  17.03.01     아파트이문동            쌍용  쌍용
# 8  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
# 9  17.03.01     아파트용두동  래미안허브리츠  래미안허브리츠
#
#                        \t\t\t공급/전용(㎡)\t\t  \t    매매가(만원)\t  \t\t\t동\t\t  \
# 0      85A/59  공급면적  85.28㎡  전용면적  59.99㎡            54000          308
# 1    111A/84  공급면적  111.47㎡  전용면적  84.99㎡            62000          310
# 2    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59500          106
# 3    111B/84  공급면적  111.82㎡  전용면적  84.96㎡            59000          108
# 4  150A/114  공급면적  150.53㎡  전용면적  114.98㎡            70000          107
# 5       89/59  공급면적  89.12㎡  전용면적  59.76㎡            39000          101
# 6       80B/59  공급면적  80.37㎡  전용면적  59.9㎡            54000          103
# 7       81/59  공급면적  81.19㎡  전용면적  59.99㎡            34000          115
# 8       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            55000          101
# 9       79A/59  공급면적  79.7㎡  전용면적  59.98㎡            54000          102
#
#   \t\t\t층\t                     \t문의처\t            비고 거래종류
# 0      저/14  황금단지내공인중개. .  02-2246-5252  매매  17.03.01  매매
# 1      중/15  황금단지내부동산공. .  02-2247-5252  매매  17.03.01  매매
# 2      5/20   미래공인중개사사무. .  02-960-6800  매매  17.03.01  매매
# 3      저/20      백산 공인중개사  02-3291-0088  매매  17.03.01  매매
# 4      중/20      백산 공인중개사  02-3291-0088  매매  17.03.01  매매
# 5      중/22  금강부동산공인중개. .  02-2245-0006  매매  17.03.01  매매
# 6      중/20      백산 공인중개사  02-3291-0088  매매  17.03.01  매매
# 7     25/25   쌍용공인중개사사무. .  02-962-2244  매매  17.03.01  매매
# 8     13/20   미래공인중개사사무. .  02-960-6800  매매  17.03.01  매매
# 9     11/19   미래공인중개사사무. .  02-960-6800  매매  17.03.01  매매

# %% [markdown]
# #### 2017 http://fb.com/financedata
